# %% [markdown]
# <h2>Problem Statement</h2><br>
# <p>The present generation is highly motivated towards the use of credit cards. There are a large number of applications for the credit card and it becomes very tedious for the bank to decide which person should be approved a credit card and which not. The list of defaulters is increasing and this brings trouble for the bank and other customers too. The bank needs ways to minimise this number for the proper functioning of the credit card feature and expand to a wider audience. It is where the role of Machine Learning and Data Science comes into play. The tedious task can be dealt with Machine Learning by training the models with minimized errors.</p>

# %% [markdown]
# <h2>Task</h2><br>
# <p>The bank has provided the data of customers with certain attributes. You need to predict if the customer would be approved a credit card or not. If the credit card is approved, it is denoted with ‘+’ and if it is not approved then it is denoted with '-'. </p>

# %% [markdown]
# <h2>Step 1: Import all required packages </h2>

# %%
#import all required packages
import os
import random
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn import preprocessing
import seaborn as sns

# %%
#import dataset
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
#Take a look at your dataset
train.head()
# Out:
#    Key Male    Age   Debt Married BankCustomer EducationLevel Ethnicity  \
# 0    1    ?  40.83  3.500       u            g              i        bb
# 1    2    ?  32.25  1.500       u            g              c         v
# 2    3    ?  28.17  0.585       u            g             aa         v
# 3    4    ?  29.75  0.665       u            g              w         v
# 4    5    ?   26.5  2.710       y            p              ?         ?
#
#    YearsEmployed PriorDefault Employed  CreditScore DriversLicense Citizen  \
# 0          0.500            f        f            0              f       s
# 1          0.250            f        f            0              t       g
# 2          0.040            f        f            0              f       g
# 3          0.250            f        f            0              t       g
# 4          0.085            f        f            0              f       s
#
#   ZipCode  Income Approved
# 0    1160       0        -
# 1     372     122        -
# 2     260    1004        -
# 3     300       0        -
# 4      80       0        -

# %%
#Check cols and rows
train.shape
# Out:
# (590, 17)

# %%
test.shape
# Out:
# (100, 16)

# %%
#Take a look at test dataset
test.head()
# Out:
#    Key Male    Age   Debt Married BankCustomer EducationLevel Ethnicity  \
# 0    1    b  31.83   0.04       y            p              m         v
# 1    2    a  21.75  11.75       u            g              c         v
# 2    3    a  17.92   0.54       u            g              c         v
# 3    4    b  30.33   0.50       u            g              d         h
# 4    5    b  51.83   2.04       y            p             ff        ff
#
#    YearsEmployed PriorDefault Employed  CreditScore DriversLicense Citizen  \
# 0          0.040            f        f            0              f       g
# 1          0.250            f        f            0              t       g
# 2          1.750            f        t            1              t       g
# 3          0.085            f        f            0              t       s
# 4          1.500            f        f            0              f       g
#
#    ZipCode  Income
# 0        0       0
# 1      180       0
# 2       80       5
# 3      252       0
# 4      120       1

# %% [markdown]
# <h2>Step 2: Data Preprocessing </h2><br>
# <ul><b>Will do following things in conversion</b>
#     <li>Conversion of Age from Object to Float </li>
#     <li>Conversion of Zipcode from Object to int</li>
#     <li>Conversion of remaining object types to category</li>
#     <li>Finally, Convert category to cat codes</li>
# </ul>
# <h2>Data cleaning</h2>
# <p>Replace NAN values with mean values of respective column instead of dropping nulls and NANs</p>

# %%
train.dtypes
# Out:
# Key                 int64
# Male               object
# Age                object
# Debt              float64
# Married            object
# BankCustomer       object
# EducationLevel     object
# Ethnicity          object
# YearsEmployed     float64
# PriorDefault       object
# Employed           object
# CreditScore         int64
# DriversLicense     object
# Citizen            object
# ZipCode            object
# Income              int64
# Approved           object
# dtype: object

# %%
train.replace('?', np.NaN, inplace = True)
test.replace('?', np.NaN, inplace = True)
train['YearsEmployed'] = [x*100 for x in train['YearsEmployed']]

# %%
#Replace ? and null values in Age column with mean age value 
train['Age'] = train['Age'].astype('float64')
train['Age'].fillna((train['Age'].mean()), inplace=True)
train.head()
# Out:
#    Key Male    Age   Debt Married BankCustomer EducationLevel Ethnicity  \
# 0    1  NaN  40.83  3.500       u            g              i        bb
# 1    2  NaN  32.25  1.500       u            g              c         v
# 2    3  NaN  28.17  0.585       u            g             aa         v
# 3    4  NaN  29.75  0.665       u            g              w         v
# 4    5  NaN  26.50  2.710       y            p            NaN       NaN
#
#    YearsEmployed PriorDefault Employed  CreditScore DriversLicense Citizen  \
# 0           50.0            f        f            0              f       s
# 1           25.0            f        f            0              t       g
# 2            4.0            f        f            0              f       g
# 3           25.0            f        f            0              t       g
# 4            8.5            f        f            0              f       s
#
#   ZipCode  Income Approved
# 0    1160       0        -
# 1     372     122        -
# 2     260    1004        -
# 3     300       0        -
# 4      80       0        -

# %%
train.isnull().sum()
# Out:
# Key                0
# Male              11
# Age                0
# Debt               0
# Married            6
# BankCustomer       6
# EducationLevel     9
# Ethnicity          9
# YearsEmployed      0
# PriorDefault       0
# Employed           0
# CreditScore        0
# DriversLicense     0
# Citizen            0
# ZipCode           13
# Income             0
# Approved           0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# Key               0
# Male              1
# Age               0
# Debt              0
# Married           0
# BankCustomer      0
# EducationLevel    0
# Ethnicity         0
# YearsEmployed     0
# PriorDefault      0
# Employed          0
# CreditScore       0
# DriversLicense    0
# Citizen           0
# ZipCode           0
# Income            0
# dtype: int64

# %%
#Covert column from object to category type

train['Married'] = train['Married'].astype('category')
train['BankCustomer'] = train['BankCustomer'].astype('category')
train['EducationLevel'] = train['EducationLevel'].astype('category')
train['Ethnicity'] = train['Ethnicity'].astype('category')
train['PriorDefault'] = train['PriorDefault'].astype('category')
train['Employed'] = train['Employed'].astype('category')
train['DriversLicense'] = train['DriversLicense'].astype('category')
train['Citizen'] = train['Citizen'].astype('category')

cat_columns = train.select_dtypes(['category']).columns
train[cat_columns] = train[cat_columns].apply(lambda x: x.cat.codes)

# %%
train.isnull().sum()
# Out:
# Key                0
# Male              11
# Age                0
# Debt               0
# Married            0
# BankCustomer       0
# EducationLevel     0
# Ethnicity          0
# YearsEmployed      0
# PriorDefault       0
# Employed           0
# CreditScore        0
# DriversLicense     0
# Citizen            0
# ZipCode           13
# Income             0
# Approved           0
# dtype: int64

# %%
train.describe()
# Out:
#               Key         Age        Debt     Married  BankCustomer  \
# count  590.000000  590.000000  590.000000  590.000000    590.000000
# mean   295.500000   31.258270    4.609390    1.227119      0.494915
# std    170.462606   11.891231    4.849569    0.493706      0.879385
# min      1.000000   13.750000    0.000000   -1.000000     -1.000000
# 25%    148.250000   22.500000    1.000000    1.000000      0.000000
# 50%    295.500000   28.375000    2.710000    1.000000      0.000000
# 75%    442.750000   37.290000    7.000000    1.750000      1.750000
# max    590.000000   80.250000   26.335000    2.000000      2.000000
#
#        EducationLevel   Ethnicity  YearsEmployed  PriorDefault   Employed  \
# count      590.000000  590.000000     590.000000    590.000000  590.00000
# mean         5.593220    4.966102     208.853390      0.493220    0.40678
# std          4.308631    2.649061     319.868126      0.500378    0.49165
# min         -1.000000   -1.000000       0.000000      0.000000    0.00000
# 25%          1.000000    3.000000      16.500000      0.000000    0.00000
# 50%          5.000000    7.000000     100.000000      0.000000    0.00000
# 75%         10.000000    7.000000     250.000000      1.000000    1.00000
# max         13.000000    8.000000    2000.000000      1.000000    1.00000
#
#        CreditScore  DriversLicense     Citizen         Income
# count   590.000000      590.000000  590.000000     590.000000
# mean      2.045763        0.445763    0.189831     918.706780
# std       3.702375        0.497471    0.575001    5025.415369
# min       0.000000        0.000000    0.000000       0.000000
# 25%       0.000000        0.000000    0.000000       0.000000
# 50%       0.000000        0.000000    0.000000       4.000000
# 75%       2.000000        1.000000    0.000000     363.000000
# max      20.000000        1.000000    2.000000  100000.000000

# %%
train
# Out:
#      Key Male       Age    Debt  Married  BankCustomer  EducationLevel  \
# 0      1  NaN  40.83000   3.500        1             0               6
# 1      2  NaN  32.25000   1.500        1             0               1
# 2      3  NaN  28.17000   0.585        1             0               0
# 3      4  NaN  29.75000   0.665        1             0              12
# 4      5  NaN  26.50000   2.710        2             2              -1
# 5      6  NaN  45.33000   1.000        1             0              10
# 6      7  NaN  42.25000   1.750        2             2              -1
# 7      8  NaN  33.17000   2.250        2             2               2
# 8      9    a  38.58000   5.000        1             0               2
# 9     10    a  19.17000   0.585        2             2               0
# 10    11    a  27.67000   1.500        1             0               9
# 11    12    a  31.25827   3.500        1             0               3
# 12    13    a  49.00000   1.500        1             0               7
# 13    14    a  28.58000   3.540        1             0               6
# 14    15    a  22.50000  11.000        2             2              10
# 15    16    a  28.50000   1.000        1             0              10
# 16    17    a  25.00000  11.000        2             2               0
# 17    18    a  19.75000   0.750        1             0               1
# 18    19    a  24.50000   1.040        2             2               5
# 19    20    a  33.75000   0.750        1             0               8
# 20    21    a  25.42000   1.125        1             0              10
# 21    22    a  20.75000   9.540        1             0               6
# 22    23    a  24.50000   1.750        2             2               1
# 23    24    a  52.17000   0.000        2             2               5
# 24    25    a  48.17000   1.335        1             0               6
# 25    26    a  20.42000  10.500        2             2              13
# 26    27    a  32.00000   6.000        1             0               3
# 27    28    a  19.17000   5.415        1             0               6
# 28    29    a  18.17000  10.000        2             2              10
# 29    30    a  16.50000   1.250        1             0              10
# ..   ...  ...       ...     ...      ...           ...             ...
# 560  561    a  20.33000  10.000        1             0               1
# 561  562    b  32.25000   0.165        2             2               1
# 562  563    b  30.17000   0.500        1             0               1
# 563  564    b  25.17000   6.000        1             0               1
# 564  565    b  39.17000   1.625        1             0               1
# 565  566    b  39.08000   6.000        1             0               9
# 566  567    b  31.67000   0.830        1             0              13
# 567  568    b  41.00000   0.040        1             0               4
# 568  569    b  48.50000   4.250        1             0               9
# 569  570    b  32.67000   9.000        2             2              12
# 570  571    a  28.08000  15.000        2             2               4
# 571  572    b  73.42000  17.750        1             0               5
# 572  573    b  64.08000  20.000        1             0              13
# 573  574    b  51.58000  15.000        1             0               1
# 574  575    b  26.67000   1.750        2             2               1
# 575  576    b  25.33000   0.580        1             0               1
# 576  577    b  30.17000   6.500        1             0               2
# 577  578    b  27.00000   0.750        1             0               1
# 578  579    b  23.17000   0.000       -1            -1              -1
# 579  580    b  34.17000   5.250        1             0              12
# 580  581    b  38.67000   0.210        1             0               8
# 581  582    b  25.75000   0.750        1             0               1
# 582  583    a  46.08000   3.000        1             0               1
# 583  584    a  21.50000   6.000        1             0               0
# 584  585  NaN  20.08000   0.125        1             0              10
# 585  586    b  20.50000   2.415        1             0               1
# 586  587    a  29.50000   0.460        1             0               8
# 587  588    b  16.17000   0.040        1             0               1
# 588  589    b  22.67000   0.165        1             0               1
# 589  590    a  25.58000   0.000       -1            -1              -1
#
#      Ethnicity  YearsEmployed  PriorDefault  Employed  CreditScore  \
# 0            0           50.0             0         0            0
# 1            7           25.0             0         0            0
# 2            7            4.0             0         0            0
# 3            7           25.0             0         0            0
# 4           -1            8.5             0         0            0
# 5            7           12.5             0         0            0
# 6           -1            0.0             0         0            0
# 7            7          350.0             0         0            0
# 8            7         1350.0             1         0            0
# 9            7           58.5             1         0            0
# 10           7          200.0             1         0            0
# 11           7          300.0             1         0            0
# 12           4            0.0             1         0            0
# 13           0           50.0             1         0            0
# 14           7          300.0             1         0            0
# 15           7          100.0             1         1            2
# 16           7          450.0             1         0            0
# 17           7           79.5             1         1            5
# 18           2           50.0             1         1            3
# 19           0          100.0             1         1            3
# 20           7          129.0             1         1            2
# 21           7            4.0             0         0            0
# 22           7           16.5             0         0            0
# 23           2            0.0             0         0            0
# 24           6           33.5             0         0            0
# 25           3            0.0             0         0            0
# 26           7          125.0             0         0            0
# 27           3           29.0             0         0            0
# 28           3           16.5             0         0            0
# 29           7           25.0             0         1            1
# ..         ...            ...           ...       ...          ...
# 560          3          100.0             1         1            4
# 561          3          325.0             1         1            1
# 562          7          175.0             1         1           11
# 563          7          100.0             1         1            3
# 564          7          150.0             1         1           10
# 565          7          129.0             1         1            5
# 566          7          133.5             1         1            8
# 567          7            4.0             0         1            1
# 568          7           12.5             1         0            0
# 569          3          525.0             1         0            0
# 570          8            0.0             1         0            0
# 571          2            0.0             1         0            0
# 572          3         1750.0             1         1            9
# 573          7          850.0             1         1            9
# 574          7          100.0             1         1            5
# 575          7           29.0             1         1            7
# 576          7          312.5             1         1            8
# 577          3          425.0             1         1            3
# 578         -1            0.0             0         0            0
# 579          7            8.5             0         0            0
# 580          7            8.5             1         0            0
# 581          0           25.0             1         0            0
# 582          7          237.5             1         1            8
# 583          7          250.0             1         1            3
# 584          7          100.0             0         1            1
# 585          7          200.0             1         1           11
# 586          7           54.0             1         1            4
# 587          7            4.0             0         0            0
# 588          4          225.0             0         0            0
# 589         -1            0.0             0         0            0
#
#      DriversLicense  Citizen ZipCode  Income Approved
# 0                 0        2    1160       0        -
# 1                 1        0     372     122        -
# 2                 0        0     260    1004        -
# 3                 1        0     300       0        -
# 4                 0        2      80       0        -
# 5                 1        0     263       0        -
# 6                 1        0     150       1        -
# 7                 1        0     200     141        -
# 8                 1        0     980       0        -
# 9                 1        0     160       0        -
# 10                0        2     368       0        -
# 11                1        0     300       0        -
# 12                1        0     100      27        -
# 13                1        0     171       0        -
# 14                1        0     268       0        -
# 15                1        0     167     500        -
# 16                0        0     120       0        -
# 17                1        0     140       5        -
# 18                0        0     180     147        -
# 19                1        0     212       0        -
# 20                0        0     200       0        -
# 21                0        0     200    1000        -
# 22                0        0     132       0        -
# 23                0        0       0       0        -
# 24                0        0       0     120        -
# 25                1        0     154      32        -
# 26                0        0     272       0        -
# 27                0        0      80     484        -
# 28                0        0     340       0        -
# 29                0        0     108      98        -
# ..              ...      ...     ...     ...      ...
# 560               0        0      50    1465        +
# 561               1        0     432    8000        +
# 562               0        0      32     540        +
# 563               0        0       0       0        +
# 564               0        0     186    4700        +
# 565               1        0     108    1097        +
# 566               1        0     303    3290        +
# 567               0        2     560       0        +
# 568               1        0     225       0        +
# 569               1        0     154       0        +
# 570               0        0       0   13212        +
# 571               1        0       0       0        +
# 572               1        0       0    1000        +
# 573               0        0       0       0        +
# 574               1        0     160    5777        +
# 575               1        0      96    5124        +
# 576               0        0     330    1200        +
# 577               1        0     312     150        +
# 578               0        1     NaN       0        +
# 579               1        0     290       6        +
# 580               1        0     280       0        +
# 581               0        0     349      23        +
# 582               1        0     396    4159        +
# 583               0        0      80     918        +
# 584               0        0     240     768        +
# 585               1        0     200    3000        +
# 586               0        0     380     500        +
# 587               0        0       0       0        +
# 588               1        2       0       0        +
# 589               0        1     NaN       0        +
#
# [590 rows x 17 columns]

# %% [markdown]
# <h2>Step 3: Encode Labels </h2>
# <p>I have used Label Encoder</p>

# %%
#Encode target class using Label Encoder 1-> - and 0 -> +
encoder = LabelEncoder()
train['Approved'] = encoder.fit_transform(train.Approved)
list(encoder.classes_)
# Out:
# ['+', '-']

# %%
train_y = train['Approved']
print(train_y[1])
print(train.Approved[1])
# Out:
# 1
# 1

# %% [markdown]
# <h2>Check if data is Imbalanced or not</h2>

# %%
#Check how many approved and not approved samples we have 
notApproved = train[train['Approved'] == '-']
approved = train[train['Approved'] == '+']
print('Total not approved',len(notApproved))
print('Total  approved',len(approved))
# Out:
# Total not approved 0
# Total  approved 0
# /home/redwuie/miniconda3/envs/py3.7.3_env/lib/python3.7/site-packages/pandas/core/ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
# Explore dataset
train.hist(figsize = (20, 20))
plt.show()

# %%
train.head()
# Out:
#    Key Male    Age   Debt  Married  BankCustomer  EducationLevel  Ethnicity  \
# 0    1  NaN  40.83  3.500        1             0               6          0
# 1    2  NaN  32.25  1.500        1             0               1          7
# 2    3  NaN  28.17  0.585        1             0               0          7
# 3    4  NaN  29.75  0.665        1             0              12          7
# 4    5  NaN  26.50  2.710        2             2              -1         -1
#
#    YearsEmployed  PriorDefault  Employed  CreditScore  DriversLicense  \
# 0           50.0             0         0            0               0
# 1           25.0             0         0            0               1
# 2            4.0             0         0            0               0
# 3           25.0             0         0            0               1
# 4            8.5             0         0            0               0
#
#    Citizen ZipCode  Income  Approved
# 0        2    1160       0         1
# 1        0     372     122         1
# 2        0     260    1004         1
# 3        0     300       0         1
# 4        2      80       0         1

# %% [markdown]
# <h2>Step 5: Feature Selection</h2>

# %%
#drop unncessary columns
train = train.drop(['Approved','ZipCode','Male'], axis=1)

# %%
train.head()
# Out:
#    Key    Age   Debt  Married  BankCustomer  EducationLevel  Ethnicity  \
# 0    1  40.83  3.500        1             0               6          0
# 1    2  32.25  1.500        1             0               1          7
# 2    3  28.17  0.585        1             0               0          7
# 3    4  29.75  0.665        1             0              12          7
# 4    5  26.50  2.710        2             2              -1         -1
#
#    YearsEmployed  PriorDefault  Employed  CreditScore  DriversLicense  \
# 0           50.0             0         0            0               0
# 1           25.0             0         0            0               1
# 2            4.0             0         0            0               0
# 3           25.0             0         0            0               1
# 4            8.5             0         0            0               0
#
#    Citizen  Income
# 0        2       0
# 1        0     122
# 2        0    1004
# 3        0       0
# 4        2       0

# %%
#Filter out Key and Approved column
X_train = train.iloc[:,1:].values
X_train
# Out:
# array([[ 4.083e+01,  3.500e+00,  1.000e+00, ...,  0.000e+00,  2.000e+00,
#          0.000e+00],
#        [ 3.225e+01,  1.500e+00,  1.000e+00, ...,  1.000e+00,  0.000e+00,
#          1.220e+02],
#        [ 2.817e+01,  5.850e-01,  1.000e+00, ...,  0.000e+00,  0.000e+00,
#          1.004e+03],
#        ...,
#        [ 1.617e+01,  4.000e-02,  1.000e+00, ...,  0.000e+00,  0.000e+00,
#          0.000e+00],
#        [ 2.267e+01,  1.650e-01,  1.000e+00, ...,  1.000e+00,  2.000e+00,
#          0.000e+00],
#        [ 2.558e+01,  0.000e+00, -1.000e+00, ...,  0.000e+00,  1.000e+00,
#          0.000e+00]])

# %%
len(train_y)
# Out:
# 590

# %% [markdown]
# <h2>Step 6: Spliting Dataset into Train and Test datasets</h2>

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_train, train_y, test_size = 0.10, random_state = 0,stratify=train_y)
len(X_test)
# Out:
# 59

# %% [markdown]
# <h2>Step 6: Fit Model</h2>
# <p>I have tried 3 different models</p>
# <li>1.LogisticRegression </li>
# <li>1.RandomForest </li>
# <li>1.Decision Tree </li>

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report, confusion_matrix,accuracy_score
import pickle
clf_lr = LogisticRegression(C=.9,max_iter=100,tol=.00001)
model = clf_lr.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(accuracy_score(y_test, y_pred))
print(f1_score(y_test, y_pred, average='macro') )
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred) )
pickle.dump(model, open('LRModel.pkl', 'wb'))
# Out:
# 0.8813559322033898
# 0.8719379844961241
# [[18  5]
#  [ 2 34]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.78      0.84        23
#            1       0.87      0.94      0.91        36
#
#     accuracy                           0.88        59
#    macro avg       0.89      0.86      0.87        59
# weighted avg       0.88      0.88      0.88        59
# /home/redwuie/miniconda3/envs/py3.7.3_env/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
from sklearn.svm import SVC
clf = SVC(gamma='auto',kernel='linear')
model = clf.fit(X_train, y_train)
y_pred1 = model.predict(X_test)
print(accuracy_score(y_test, y_pred1))
print(f1_score(y_test, y_pred1, average='macro') )
print(confusion_matrix(y_test, y_pred1))
print(classification_report(y_test, y_pred1) )
# Out:
# 0.864406779661017
# 0.8521303258145363
# [[17  6]
#  [ 2 34]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.74      0.81        23
#            1       0.85      0.94      0.89        36
#
#     accuracy                           0.86        59
#    macro avg       0.87      0.84      0.85        59
# weighted avg       0.87      0.86      0.86        59

# %% [markdown]
# <h2>Check predictions that got wrong</h2>

# %% [markdown]
# <h2>Plot graph of Confusion Matrix</h2>

# %%
cm = confusion_matrix(y_test, y_pred)
score = model.score(X_test, y_test)
plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(score)
plt.title(all_sample_title, size = 15);

# %% [markdown]
# <h2>Step 7. Prepare Test Data</h2>

# %%
test = pd.read_csv('test.csv')
test.head()
# Out:
#    Key Male    Age   Debt Married BankCustomer EducationLevel Ethnicity  \
# 0    1    b  31.83   0.04       y            p              m         v
# 1    2    a  21.75  11.75       u            g              c         v
# 2    3    a  17.92   0.54       u            g              c         v
# 3    4    b  30.33   0.50       u            g              d         h
# 4    5    b  51.83   2.04       y            p             ff        ff
#
#    YearsEmployed PriorDefault Employed  CreditScore DriversLicense Citizen  \
# 0          0.040            f        f            0              f       g
# 1          0.250            f        f            0              t       g
# 2          1.750            f        t            1              t       g
# 3          0.085            f        f            0              t       s
# 4          1.500            f        f            0              f       g
#
#    ZipCode  Income
# 0        0       0
# 1      180       0
# 2       80       5
# 3      252       0
# 4      120       1

# %%
test.describe()
# Out:
#               Key         Age        Debt  YearsEmployed  CreditScore  \
# count  100.000000  100.000000  100.000000     100.000000   100.000000
# mean    50.500000   33.359400    5.639800       3.019150     4.490000
# std     29.011492   11.521954    5.624441       4.039917     8.824318
# min      1.000000   15.830000    0.000000       0.000000     0.000000
# 25%     25.750000   23.397500    1.000000       0.500000     0.000000
# 50%     50.500000   30.705000    4.125000       1.667500     1.000000
# 75%     75.250000   41.252500    9.508750       4.376250     6.000000
# max    100.000000   58.670000   28.000000      28.500000    67.000000
#
#           ZipCode        Income
# count  100.000000    100.000000
# mean   174.170000   1599.590000
# std    159.721225   6185.926674
# min      0.000000      0.000000
# 25%      0.000000      0.000000
# 50%    142.500000     26.000000
# 75%    260.000000    509.250000
# max    711.000000  50000.000000

# %%
test.dtypes
# Out:
# Key                 int64
# Male               object
# Age               float64
# Debt              float64
# Married            object
# BankCustomer       object
# EducationLevel     object
# Ethnicity          object
# YearsEmployed     float64
# PriorDefault       object
# Employed           object
# CreditScore         int64
# DriversLicense     object
# Citizen            object
# ZipCode             int64
# Income              int64
# dtype: object

# %%
test['YearsEmployed'] = [x*100 for x in test['YearsEmployed']]

# %% [markdown]
# <h2>Test Data Cleaning :  Apply same operations that we did for Train Dataset</h2>

# %%
test['numericAge'] = test.loc[test.Age != '?', 'Age']
test['numericAge'] = test['numericAge'].astype('float64')
print('Mean Age ',test['numericAge'].mean())
test.loc[test.Age == '?', 'Age'] = test['numericAge'].mean()
test['Age'] = test['Age'].astype('float64')
test['Age'].fillna((test['Age'].mean()), inplace=True)
# Out:
# Mean Age  33.35940000000001
# /home/redwuie/miniconda3/envs/py3.7.3_env/lib/python3.7/site-packages/pandas/core/ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
test['numericZip'] = test.loc[test.ZipCode != '?', 'ZipCode']
s = test['numericZip'].value_counts()
test.loc[test.ZipCode == '?', 'ZipCode'] = s.index[-1]
test['ZipCode'] = test['ZipCode'].astype('int64')
test['ZipCode'].fillna(s.index[0], inplace=True)

# %%
test['Male'] = test['Male'].astype('category')
test['Married'] = test['Married'].astype('category')
test['BankCustomer'] = test['BankCustomer'].astype('category')
test['EducationLevel'] = test['EducationLevel'].astype('category')
test['Ethnicity'] = test['Ethnicity'].astype('category')
test['PriorDefault'] = test['PriorDefault'].astype('category')
test['Employed'] = test['Employed'].astype('category')
test['DriversLicense'] = test['DriversLicense'].astype('category')
test['Citizen'] = test['Citizen'].astype('category')

cat_columns = test.select_dtypes(['category']).columns
test[cat_columns] = test[cat_columns].apply(lambda x: x.cat.codes)

# %%
test.describe()
# Out:
#               Key        Male         Age        Debt    Married  \
# count  100.000000  100.000000  100.000000  100.000000  100.00000
# mean    50.500000    1.670000   33.359400    5.639800    0.15000
# std     29.011492    0.493493   11.521954    5.624441    0.35887
# min      1.000000    0.000000   15.830000    0.000000    0.00000
# 25%     25.750000    1.000000   23.397500    1.000000    0.00000
# 50%     50.500000    2.000000   30.705000    4.125000    0.00000
# 75%     75.250000    2.000000   41.252500    9.508750    0.00000
# max    100.000000    2.000000   58.670000   28.000000    1.00000
#
#        BankCustomer  EducationLevel   Ethnicity  YearsEmployed  PriorDefault  \
# count     100.00000      100.000000  100.000000     100.000000    100.000000
# mean        0.15000        5.680000    2.460000     301.915000      0.700000
# std         0.35887        3.925776    0.757721     403.991743      0.460566
# min         0.00000        0.000000    0.000000       0.000000      0.000000
# 25%         0.00000        2.000000    2.000000      50.000000      0.000000
# 50%         0.00000        6.000000    3.000000     166.750000      1.000000
# 75%         0.00000        9.000000    3.000000     437.625000      1.000000
# max         1.00000       12.000000    3.000000    2850.000000      1.000000
#
#        Employed  CreditScore  DriversLicense     Citizen     ZipCode  \
# count    100.00   100.000000      100.000000  100.000000  100.000000
# mean       0.55     4.490000        0.530000    0.050000  174.170000
# std        0.50     8.824318        0.501614    0.219043  159.721225
# min        0.00     0.000000        0.000000    0.000000    0.000000
# 25%        0.00     0.000000        0.000000    0.000000    0.000000
# 50%        1.00     1.000000        1.000000    0.000000  142.500000
# 75%        1.00     6.000000        1.000000    0.000000  260.000000
# max        1.00    67.000000        1.000000    1.000000  711.000000
#
#              Income  numericAge  numericZip
# count    100.000000  100.000000  100.000000
# mean    1599.590000   33.359400  174.170000
# std     6185.926674   11.521954  159.721225
# min        0.000000   15.830000    0.000000
# 25%        0.000000   23.397500    0.000000
# 50%       26.000000   30.705000  142.500000
# 75%      509.250000   41.252500  260.000000
# max    50000.000000   58.670000  711.000000

# %%
test.shape
test.head()
# Out:
#    Key  Male    Age   Debt  Married  BankCustomer  EducationLevel  Ethnicity  \
# 0    1     2  31.83   0.04        1             1               8          3
# 1    2     1  21.75  11.75        0             0               1          3
# 2    3     1  17.92   0.54        0             0               1          3
# 3    4     2  30.33   0.50        0             0               3          2
# 4    5     2  51.83   2.04        1             1               5          1
#
#    YearsEmployed  PriorDefault  Employed  CreditScore  DriversLicense  \
# 0            4.0             0         0            0               0
# 1           25.0             0         0            0               1
# 2          175.0             0         1            1               1
# 3            8.5             0         0            0               1
# 4          150.0             0         0            0               0
#
#    Citizen  ZipCode  Income  numericAge  numericZip
# 0        0        0       0       31.83           0
# 1        0      180       0       21.75         180
# 2        0       80       5       17.92          80
# 3        1      252       0       30.33         252
# 4        0      120       1       51.83         120

# %% [markdown]
# <h2>Selecting Feature</h2>

# %%
test = test.drop(['numericAge', 'numericZip','ZipCode','Male'], axis=1)
X_test = test.iloc[:,1:].values
X_test
# Out:
# array([[3.1830e+01, 4.0000e-02, 1.0000e+00, ..., 0.0000e+00, 0.0000e+00,
#         0.0000e+00],
#        [2.1750e+01, 1.1750e+01, 0.0000e+00, ..., 1.0000e+00, 0.0000e+00,
#         0.0000e+00],
#        [1.7920e+01, 5.4000e-01, 0.0000e+00, ..., 1.0000e+00, 0.0000e+00,
#         5.0000e+00],
#        ...,
#        [2.0750e+01, 1.0335e+01, 0.0000e+00, ..., 1.0000e+00, 0.0000e+00,
#         5.0000e+01],
#        [3.9920e+01, 6.2100e+00, 0.0000e+00, ..., 0.0000e+00, 0.0000e+00,
#         3.0000e+02],
#        [2.5670e+01, 1.2500e+01, 0.0000e+00, ..., 1.0000e+00, 0.0000e+00,
#         2.5800e+02]])

# %% [markdown]
# <h2>Apply LogisticRegression<h2>

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix,accuracy_score

clf_lr = LogisticRegression(C=.9)
model = clf_lr.fit(X_train, y_train)
y_pred = model.predict(X_test)
# Out:
# /home/redwuie/miniconda3/envs/py3.7.3_env/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %% [markdown]
# <h2>Save Predictions</h2>

# %%
df1 = pd.DataFrame()
df1['Key'] = test['Key']

# %%
df1['Approved'] = encoder.inverse_transform(y_pred)

# %%
df1.reset_index(drop=True)

# %% [markdown]
# <h2>Save final dataframe to CSV</h2>

# %%
df1.to_csv('FinalSolutionL7.csv',index=False)

# %%
model_loaded = pickle.load(open('LRModel.pkl', 'rb'))

# %%
model_loaded.predict_proba(X_test)
# Out:
# array([[8.61187079e-02, 9.13881292e-01],
#        [1.90298382e-01, 8.09701618e-01],
#        [3.93520162e-01, 6.06479838e-01],
#        [1.84675226e-01, 8.15324774e-01],
#        [7.31324081e-02, 9.26867592e-01],
#        [3.72598360e-01, 6.27401640e-01],
#        [2.48410396e-01, 7.51589604e-01],
#        [1.53593660e-01, 8.46406340e-01],
#        [9.59667906e-02, 9.04033209e-01],
#        [2.52890212e-01, 7.47109788e-01],
#        [2.29445087e-01, 7.70554913e-01],
#        [7.28981345e-01, 2.71018655e-01],
#        [4.69781886e-01, 5.30218114e-01],
#        [2.63488020e-01, 7.36511980e-01],
#        [2.43560497e-01, 7.56439503e-01],
#        [3.13128787e-01, 6.86871213e-01],
#        [1.28701442e-01, 8.71298558e-01],
#        [2.19149169e-01, 7.80850831e-01],
#        [7.75923216e-02, 9.22407678e-01],
#        [2.52879062e-01, 7.47120938e-01],
#        [9.67516013e-02, 9.03248399e-01],
#        [4.64593817e-01, 5.35406183e-01],
#        [1.54006727e-01, 8.45993273e-01],
#        [3.10744429e-01, 6.89255571e-01],
#        [3.17026262e-01, 6.82973738e-01],
#        [9.53144247e-01, 4.68557533e-02],
#        [9.77923158e-01, 2.20768420e-02],
#        [9.29578837e-01, 7.04211628e-02],
#        [9.71929130e-01, 2.80708697e-02],
#        [9.17702311e-01, 8.22976885e-02],
#        [8.70648415e-01, 1.29351585e-01],
#        [9.99999918e-01, 8.21213697e-08],
#        [9.26537773e-01, 7.34622268e-02],
#        [7.23834430e-01, 2.76165570e-01],
#        [7.86621121e-01, 2.13378879e-01],
#        [2.17513794e-01, 7.82486206e-01],
#        [9.12641968e-01, 8.73580318e-02],
#        [8.40060769e-01, 1.59939231e-01],
#        [4.81544021e-01, 5.18455979e-01],
#        [9.76401011e-01, 2.35989890e-02],
#        [9.17256389e-01, 8.27436108e-02],
#        [9.47161160e-01, 5.28388400e-02],
#        [9.90341846e-01, 9.65815367e-03],
#        [8.41793961e-01, 1.58206039e-01],
#        [9.75641056e-01, 2.43589443e-02],
#        [9.96868769e-01, 3.13123054e-03],
#        [8.84335383e-01, 1.15664617e-01],
#        [9.85625550e-01, 1.43744502e-02],
#        [9.63071270e-01, 3.69287303e-02],
#        [9.38700810e-01, 6.12991902e-02],
#        [9.55608629e-01, 4.43913713e-02],
#        [9.79523201e-01, 2.04767992e-02],
#        [9.97170748e-01, 2.82925177e-03],
#        [9.68612371e-01, 3.13876292e-02],
#        [9.99705574e-01, 2.94426364e-04],
#        [9.67755853e-01, 3.22441474e-02],
#        [9.90051923e-01, 9.94807723e-03],
#        [9.99233059e-01, 7.66941363e-04],
#        [9.78323043e-01, 2.16769573e-02],
#        [9.69335341e-01, 3.06646592e-02],
#        [9.85507331e-01, 1.44926690e-02],
#        [9.87937439e-01, 1.20625610e-02],
#        [9.56191536e-01, 4.38084640e-02],
#        [8.58208530e-01, 1.41791470e-01],
#        [9.94392741e-01, 5.60725888e-03],
#        [9.87850394e-01, 1.21496057e-02],
#        [9.96443526e-01, 3.55647436e-03],
#        [9.52336605e-01, 4.76633954e-02],
#        [9.83448064e-01, 1.65519362e-02],
#        [9.99933896e-01, 6.61043639e-05],
#        [9.79095401e-01, 2.09045993e-02],
#        [9.91473678e-01, 8.52632226e-03],
#        [9.75425868e-01, 2.45741318e-02],
#        [2.81683570e-01, 7.18316430e-01],
#        [2.39173961e-01, 7.60826039e-01],
#        [8.32376856e-01, 1.67623144e-01],
#        [8.71547028e-01, 1.28452972e-01],
#        [9.85970751e-01, 1.40292493e-02],
#        [8.54990160e-01, 1.45009840e-01],
#        [9.03019528e-01, 9.69804719e-02],
#        [6.80834461e-01, 3.19165539e-01],
#        [8.72747148e-01, 1.27252852e-01],
#        [8.77104788e-01, 1.22895212e-01],
#        [3.29569848e-01, 6.70430152e-01],
#        [9.91188088e-01, 8.81191241e-03],
#        [9.40611955e-01, 5.93880452e-02],
#        [9.88533970e-01, 1.14660296e-02],
#        [8.55317015e-01, 1.44682985e-01],
#        [9.57313760e-01, 4.26862400e-02],
#        [9.44135369e-01, 5.58646309e-02],
#        [1.00000000e+00, 1.72320363e-11],
#        [9.87908882e-01, 1.20911182e-02],
#        [9.99950762e-01, 4.92380128e-05],
#        [9.95052379e-01, 4.94762114e-03],
#        [9.48768430e-01, 5.12315702e-02],
#        [9.99962749e-01, 3.72506322e-05],
#        [9.93133288e-01, 6.86671184e-03],
#        [9.22407735e-01, 7.75922648e-02],
#        [9.46676464e-01, 5.33235363e-02],
#        [9.99993475e-01, 6.52529067e-06]])

# %%
df=pd.read_csv('default//test.csv')

# %%
df.head()
# Out:
#    Key Male    Age   Debt Married BankCustomer EducationLevel Ethnicity  \
# 0    1    ?  40.83  3.500       u            g              i        bb
# 1    2    ?  32.25  1.500       u            g              c         v
# 2    3    ?  28.17  0.585       u            g             aa         v
# 3    4    ?  29.75  0.665       u            g              w         v
# 4    5    ?   26.5  2.710       y            p              ?         ?
#
#    YearsEmployed PriorDefault Employed  CreditScore DriversLicense Citizen  \
# 0          0.500            f        f            0              f       s
# 1          0.250            f        f            0              t       g
# 2          0.040            f        f            0              f       g
# 3          0.250            f        f            0              t       g
# 4          0.085            f        f            0              f       s
#
#    ZipCode  Income
# 0     1160       0
# 1      372     122
# 2      260    1004
# 3      300       0
# 4       80       0
